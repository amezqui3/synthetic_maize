# %% [markdown]
# # Allometry

# %%
import matplotlib.pyplot as plt
import numpy as np
import numpy.polynomial.polynomial as P
import pandas as pd
import glob
import os
import math
import importlib
from sklearn.metrics import r2_score
# %matplotlib inline

import amaizeing_utils as maize

# %% [markdown]
# ## Load model data files

# %%
src = '../model/'
model_files = sorted(glob.glob(src+'*.csv'))
model_files
# Out:
# ['../model/LPlant.L1_poly_model.csv',
#  '../model/LPlant.L2_poly_model.csv',
#  '../model/RPlant.L1_poly_model.csv',
#  '../model/RPlant.L2_poly_model.csv']

# %%
i = 1
data = pd.read_csv(model_files[i])
data = data.set_index('Unnamed: 0')
data.index.rename('idx', inplace=True)
data.head()
# Out:
#             plot  Pass  Range  Rep  New_Pedigree  Old_Pedigree Old_Source  \
# idx
# 0    MIH119_1001     3      2    1  2369/LH123HT  2369/LH123HT        NaN
# 1    MIH119_1002     4      2    1  2369/LH123HT  2369/LH123HT        NaN
# 2    MIH119_1003     5      2    1       B37/H95     B73/PHN82        NaN
# 3    MIH119_1004     6      2    1       B37/H95      B14A/H95        NaN
# 6    MIH119_1007     9      2    1       B37/H95      B73/MO17        NaN
#
#      Shared  LPlant.L2.End.Angle  LPlant.L2.End.Length  ...        A1  \
# idx                                                     ...
# 0       1.0                   51                  32.0  ...  0.227513
# 1       1.0                   83                  40.0  ...  0.000757
# 2       NaN                   47                  39.0  ...  0.549855
# 3       NaN                   78                  39.0  ...  0.027698
# 6       NaN                   59                  44.0  ...  0.002691
#
#            N1        A2        N2          a          b          c          d  \
# idx
# 0    1.740284 -3.792795  1.302024  20.708295  24.868671  44.409082  20.138253
# 1    3.007398 -1.926790  1.818836  35.247650  39.701846  34.038260   4.874774
# 2    1.435147 -2.176995  1.337701  22.821386  28.522794  48.940620  26.597936
# 3    2.050304 -1.077360  1.480416  30.405592  38.147756  30.405592   8.108556
# 6    2.808379 -2.311190  1.339725  32.120280  37.715361  45.872514  22.661675
#
#         length  curled
# idx
# 0    74.867052     0.0
# 1    83.318879     0.0
# 2    77.712970     0.0
# 3    68.906309     0.0
# 6    84.791674     0.0
#
# [5 rows x 23 columns]

# %%
for i,c in enumerate(data.columns):
    print(i,'\t',c)
# Out:
# 0 	 plot
# 1 	 Pass
# 2 	 Range
# 3 	 Rep
# 4 	 New_Pedigree
# 5 	 Old_Pedigree
# 6 	 Old_Source
# 7 	 Shared
# 8 	 LPlant.L2.End.Angle
# 9 	 LPlant.L2.End.Length
# 10 	 LPlant.L2.Mid.Angle
# 11 	 LPlant.L2.Mid.Length
# 12 	 LPlant.L2.Stem.Angle
# 13 	 A1
# 14 	 N1
# 15 	 A2
# 16 	 N2
# 17 	 a
# 18 	 b
# 19 	 c
# 20 	 d
# 21 	 length
# 22 	 curled

# %%
importlib.reload(maize)
i = 21
write_file = True
cutoff = 160
dst = '../model/allometry_LPlantL2/'
X, Y, R2 = [], [], []
for i in range(8,21):
    for j in range(i+1,21):
        x,y,r2 = maize.fit_allometry(data, i,j, plot_fig=True,w=write_file, dst=dst)
        R2.append(r2)
        X.append(x)
        Y.append(y)
R2 = np.array(R2)

# %%
allometry = pd.DataFrame((X,Y,R2), index=['X','Y','R2']).T
allometry.sort_values(by=['R2'], ascending=False)
# Out:
#                        X                     Y           R2
# 50                    A1                    N1     0.920429
# 63                    A2                    N2     0.793849
# 20  LPlant.L2.End.Length                     b     0.720889
# 29   LPlant.L2.Mid.Angle                     a     0.651654
# 11   LPlant.L2.End.Angle                     d     0.577688
# ..                   ...                   ...          ...
# 36  LPlant.L2.Mid.Length                    A2   0.00131938
# 23   LPlant.L2.Mid.Angle  LPlant.L2.Mid.Length  0.000613892
# 74                     a                     d  0.000413022
# 69                    N2                     b  0.000248356
# 51                    A1                    A2  1.32999e-06
#
# [78 rows x 3 columns]

# %%
plt.figure(figsize=(12,3))
plt.plot(np.sort(R2)[::-1], 'ob')
plt.title('Sorted R2 values', fontsize=20)
plt.ylabel('R2', fontsize=18)
# Out:
# Text(0, 0.5, 'R2')
