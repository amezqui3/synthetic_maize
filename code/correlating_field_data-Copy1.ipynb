# %%
import numpy as np
import pandas as pd
import seaborn as sns

import matplotlib.pyplot as plt
# %matplotlib inline

# %%
src = '../2019_G2F_Shared/'
dst = '../model/field_data/'

data_file = 'merged_data.csv'

data = pd.read_csv(src + data_file)
#data = pd.read_csv('../field_data/merged_data.csv')
print(data.shape)
for i,c in enumerate(data.columns):
    print(i,'\t',c)
# Out:
# (368, 220)
# 0 	 plot
# 1 	 New_Source
# 2 	 New_Pedigree
# 3 	 Old_Pedigree
# 4 	 Old_Source
# 5 	 Shared
# 6 	 New_Family
# 7 	 Tester
# 8 	 Pass
# 9 	 Range
# 10 	 Group.1
# 11 	 Rep
# 12 	 Date.Time
# 13 	 Harvest.Sequence
# 14 	 X
# 15 	 Stand.Count
# 16 	 GreenSnap
# 17 	 Root Lodging
# 18 	 Stalk Lodging
# 19 	 canopy_cover
# 20 	 Weight
# 21 	 Moisture
# 22 	 Test.Weight
# 23 	 yield_originaal_moisture
# 24 	 yield_dry
# 25 	 yield_standard
# 26 	 yield_standard_bu
# 27 	 yield_dry_gm
# 28 	 dry_matter/plant(kg)
# 29 	 Ear_Leaf_Length (cm)
# 30 	 Ear_Leaf_Width (cm)
# 31 	 Ear_Leaf_Area (cm^2)
# 32 	 Ear_Height (cm)
# 33 	 Plant_Height (cm)
# 34 	 Ear_Leaf_N
# 35 	 Total_Leaf_N
# 36 	 AnthesisGDD
# 37 	 SilkingGDD
# 38 	 TLA (m2)
# 39 	 epd
# 40 	 ear_leaf_weight (g)
# 41 	 LAI
# 42 	 BLUE_2019702dronemean
# 43 	 BLUE_STD_2019702dronemean
# 44 	 GREEN_2019702dronemean
# 45 	 GREEN_STD_2019702dronemean
# 46 	 NDVI_2019702dronemean
# 47 	 NDVI_STD_2019702dronemean
# 48 	 NIR_2019702dronemean
# 49 	 NIR_STD_2019702dronemean
# 50 	 RED_2019702dronemean
# 51 	 RED_STD_2019702dronemean
# 52 	 RED_EDGE_2019702dronemean
# 53 	 RED_EDGE_STD_2019702dronemean
# 54 	 BGI_72_mean_2019702dronemean
# 55 	 BGI_72_STD_2019702dronemean
# 56 	 EVI_72_mean_2019702dronemean
# 57 	 EVI_72_STD_2019702dronemean
# 58 	 GNDVI_72_mean_2019702dronemean
# 59 	 GNDVI_72_STD_2019702dronemean
# 60 	 Ratio_72_mean_2019702dronemean
# 61 	 Ratio_72_STD_2019702dronemean
# 62 	 SAVI_72_mean_2019702dronemean
# 63 	 SAVI_72_STD_2019702dronemean
# 64 	 TVI_72_mean_2019702dronemean
# 65 	 TVI_72_STD_2019702dronemean
# 66 	 BLUE_2019715dronemean
# 67 	 BLUE_STD_2019715dronemean
# 68 	 GREEN_2019715dronemean
# 69 	 GREEN_STD_2019715dronemean
# 70 	 NDVI_2019715dronemean
# 71 	 NDVI_STD_2019715dronemean
# 72 	 NIR_2019715dronemean
# 73 	 NIR_STD_2019715dronemean
# 74 	 RED_2019715dronemean
# 75 	 RED_STD_2019715dronemean
# 76 	 RED_EDGE_2019715dronemean
# 77 	 RED_EDGE_STD_2019715dronemean
# 78 	 BGI_715_mean
# 79 	 BGI_715_STD
# 80 	 EVI_715_mean
# 81 	 EVI_715_STD
# 82 	 GNDVI_715_mean
# 83 	 GNDVI_715_STD
# 84 	 Ratio_715_mean
# 85 	 Ratio_715_STD
# 86 	 SAVI_715_mean
# 87 	 SAVI_715_STD
# 88 	 TVI_715_mean
# 89 	 TVI_715_STD
# 90 	 BLUE_2019728dronemean
# 91 	 BLUE_STD_2019728dronemean
# 92 	 GREEN_2019728dronemean
# 93 	 GREEN_STD_2019728dronemean
# 94 	 NDVI_2019728dronemean
# 95 	 NDVI_STD_2019728dronemean
# 96 	 NIR_2019728dronemean
# 97 	 NIR_STD_2019728dronemean
# 98 	 RED_2019728dronemean
# 99 	 RED_STD_2019728dronemean
# 100 	 RED_EDGE_2019728dronemean
# 101 	 RED_EDGE_STD_2019728dronemean
# 102 	 BGI_728_mean
# 103 	 BGI_728_STD
# 104 	 EVI_728_mean
# 105 	 EVI_728_STD
# 106 	 GNDVI_728_mean
# 107 	 GNDVI_728_STD
# 108 	 Ratio_728_mean
# 109 	 Ratio_728_STD
# 110 	 SAVI_728_mean
# 111 	 SAVI_728_STD
# 112 	 TVI_728_mean
# 113 	 TVI_728_STD
# 114 	 BLUE_2019812dronemean
# 115 	 BLUE_STD_2019812dronemean
# 116 	 GREEN_2019812dronemean
# 117 	 GREEN_STD_2019812dronemean
# 118 	 NDVI_2019812dronemean
# 119 	 NDVI_STD_2019812dronemean
# 120 	 NIR_2019812dronemean
# 121 	 NIR_STD_2019812dronemean
# 122 	 RED_2019812dronemean
# 123 	 RED_STD_2019812dronemean
# 124 	 RED_EDGE_2019812dronemean
# 125 	 RED_EDGE_STD_2019812dronemean
# 126 	 BGI_812_mean
# 127 	 BGI_812_STD
# 128 	 EVI_812_mean
# 129 	 EVI_812_STD
# 130 	 GNDVI_812_mean
# 131 	 GNDVI_812_STD
# 132 	 Ratio_812_mean
# 133 	 Ratio_812_STD
# 134 	 SAVI_812_mean
# 135 	 SAVI_812_STD
# 136 	 TVI_812_mean
# 137 	 TVI_812_STD
# 138 	 BLUE_2019902dronemean
# 139 	 BLUE_STD_2019902dronemean
# 140 	 GREEN_2019902dronemean
# 141 	 GREEN_STD_2019902dronemean
# 142 	 NDVI_2019902dronemean
# 143 	 NDVI_STD_2019902dronemean
# 144 	 NIR_2019902dronemean
# 145 	 NIR_STD_2019902dronemean
# 146 	 RED_2019902dronemean
# 147 	 RED_STD_2019902dronemean
# 148 	 RED_EDGE_2019902dronemean
# 149 	 RED_EDGE_STD_2019902dronemean
# 150 	 BGI_92_mean
# 151 	 BGI_92_STD
# 152 	 EVI_92_mean
# 153 	 EVI_92_STD
# 154 	 GNDVI_92_mean
# 155 	 GNDVI_92_STD
# 156 	 Ratio_92_mean
# 157 	 Ratio_92_STD
# 158 	 SAVI_92_mean
# 159 	 SAVI_92_STD
# 160 	 TVI_92_mean
# 161 	 TVI_92_STD
# 162 	 BLUE_2019911dronemean
# 163 	 BLUE_STD_2019911dronemean
# 164 	 GREEN_2019911dronemean
# 165 	 GREEN_STD_2019911dronemean
# 166 	 NDVI_2019911dronemean
# 167 	 NDVI_STD_2019911dronemean
# 168 	 NIR_2019911dronemean
# 169 	 NIR_STD_2019911dronemean
# 170 	 RED_2019911dronemean
# 171 	 RED_STD_2019911dronemean
# 172 	 RED_EDGE_2019911dronemean
# 173 	 RED_EDGE_STD_2019911dronemean
# 174 	 BGI_911_mean
# 175 	 BGI_911_STD
# 176 	 EVI_911_mean
# 177 	 EVI_911_STD
# 178 	 GNDVI_911_mean
# 179 	 GNDVI_911_STD
# 180 	 Ratio_911_mean
# 181 	 Ratio_911_STD
# 182 	 SAVI_911_mean
# 183 	 SAVI_911_STD
# 184 	 TVI_911_mean
# 185 	 TVI_911_STD
# 186 	 2019-07-02 00:00:00
# 187 	 2019-07-15 00:00:00
# 188 	 2019-07-28 00:00:00
# 189 	 2019-08-12 00:00:00
# 190 	 2019-09-02 00:00:00
# 191 	 2019-09-11 00:00:00
# 192 	 End.Angle_L1
# 193 	 End.Length_L1
# 194 	 Mid.Angle_L1
# 195 	 Mid.Length_L1
# 196 	 Stem.Angle_L1
# 197 	 A1_L1
# 198 	 N1_L1
# 199 	 A2_L1
# 200 	 N2_L1
# 201 	 a_L1
# 202 	 b_L1
# 203 	 c_L1
# 204 	 d_L1
# 205 	 model_leaf_length_L1
# 206 	 End.Angle_L2
# 207 	 End.Length_L2
# 208 	 Mid.Angle_L2
# 209 	 Mid.Length_L2
# 210 	 Stem.Angle_L2
# 211 	 A1_L2
# 212 	 N1_L2
# 213 	 A2_L2
# 214 	 N2_L2
# 215 	 a_L2
# 216 	 b_L2
# 217 	 c_L2
# 218 	 d_L2
# 219 	 model_leaf_length_L2

# %%
pcorr = data.iloc[:,19:].corr(method='pearson')
pcorr
# Out:
#                           canopy_cover    Weight  Moisture  Test.Weight  \
# canopy_cover                  1.000000  0.414782  0.029320    -0.086161
# Weight                        0.414782  1.000000  0.151360    -0.141721
# Moisture                      0.029320  0.151360  1.000000    -0.261202
# Test.Weight                  -0.086161 -0.141721 -0.261202     1.000000
# yield_originaal_moisture      0.414782  1.000000  0.151360    -0.141721
# ...                                ...       ...       ...          ...
# a_L2                          0.130444  0.035502 -0.188861     0.076124
# b_L2                          0.180357  0.017263 -0.169051     0.121206
# c_L2                         -0.006778  0.207669  0.059062    -0.088037
# d_L2                         -0.020636  0.121527 -0.016200    -0.058896
# model_leaf_length_L2          0.121914  0.194952 -0.035132     0.020646
#
#                           yield_originaal_moisture  yield_dry  yield_standard  \
# canopy_cover                              0.414782   0.421843        0.421843
# Weight                                    1.000000   0.992655        0.992655
# Moisture                                  0.151360   0.038517        0.038517
# Test.Weight                              -0.141721  -0.109274       -0.109274
# yield_originaal_moisture                  1.000000   0.992655        0.992655
# ...                                            ...        ...             ...
# a_L2                                      0.035502   0.058256        0.058256
# b_L2                                      0.017263   0.038205        0.038205
# c_L2                                      0.207669   0.203304        0.203304
# d_L2                                      0.121527   0.126371        0.126371
# model_leaf_length_L2                      0.194952   0.201090        0.201090
#
#                           yield_standard_bu  yield_dry_gm  \
# canopy_cover                       0.415222      0.421843
# Weight                             0.985747      0.992655
# Moisture                           0.111759      0.038517
# Test.Weight                       -0.274143     -0.109274
# yield_originaal_moisture           0.985747      0.992655
# ...                                     ...           ...
# a_L2                               0.031689      0.058256
# b_L2                               0.005717      0.038205
# c_L2                               0.210624      0.203304
# d_L2                               0.129483      0.126371
# model_leaf_length_L2               0.183567      0.201090
#
#                           dry_matter/plant(kg)  ...  Stem.Angle_L2     A1_L2  \
# canopy_cover                         -0.182845  ...       0.054126 -0.015386
# Weight                                0.569922  ...      -0.104689  0.048855
# Moisture                             -0.073181  ...       0.005644  0.157589
# Test.Weight                          -0.111165  ...       0.038350 -0.103579
# yield_originaal_moisture              0.569922  ...      -0.104689  0.048855
# ...                                        ...  ...            ...       ...
# a_L2                                  0.039499  ...       0.316881 -0.444161
# b_L2                                  0.001245  ...       0.325427 -0.273498
# c_L2                                  0.241992  ...      -0.485779  0.379130
# d_L2                                  0.171895  ...      -0.313112  0.169182
# model_leaf_length_L2                  0.185535  ...      -0.274334  0.098476
#
#                              N1_L2     A2_L2     N2_L2      a_L2      b_L2  \
# canopy_cover              0.026227  0.062696  0.036528  0.130444  0.180357
# Weight                    0.007301  0.042297  0.054092  0.035502  0.017263
# Moisture                 -0.134478 -0.082195  0.015840 -0.188861 -0.169051
# Test.Weight               0.059264  0.038000 -0.032486  0.076124  0.121206
# yield_originaal_moisture  0.007301  0.042297  0.054092  0.035502  0.017263
# ...                            ...       ...       ...       ...       ...
# a_L2                      0.389459  0.071190 -0.131168  1.000000  0.651822
# b_L2                      0.198237  0.446563  0.175147  0.651822  1.000000
# c_L2                     -0.205499  0.005641  0.180535 -0.121716 -0.184263
# d_L2                     -0.118128  0.169197  0.391445  0.060653 -0.016461
# model_leaf_length_L2      0.194631  0.154758  0.172589  0.289354  0.489477
#
#                               c_L2      d_L2  model_leaf_length_L2
# canopy_cover             -0.006778 -0.020636              0.121914
# Weight                    0.207669  0.121527              0.194952
# Moisture                  0.059062 -0.016200             -0.035132
# Test.Weight              -0.088037 -0.058896              0.020646
# yield_originaal_moisture  0.207669  0.121527              0.194952
# ...                            ...       ...                   ...
# a_L2                     -0.121716  0.060653              0.289354
# b_L2                     -0.184263 -0.016461              0.489477
# c_L2                      1.000000  0.762509              0.474770
# d_L2                      0.762509  1.000000              0.103322
# model_leaf_length_L2      0.474770  0.103322              1.000000
#
# [201 rows x 201 columns]

# %%
scorr = data.iloc[:,19:].corr(method='spearman')
scorr
# Out:
#                           canopy_cover    Weight  Moisture  Test.Weight  \
# canopy_cover                  1.000000  0.330251  0.015230    -0.003358
# Weight                        0.330251  1.000000  0.146985    -0.181027
# Moisture                      0.015230  0.146985  1.000000    -0.546024
# Test.Weight                  -0.003358 -0.181027 -0.546024     1.000000
# yield_originaal_moisture      0.330251  1.000000  0.146985    -0.181027
# ...                                ...       ...       ...          ...
# a_L2                          0.176139  0.040943 -0.181117     0.152330
# b_L2                          0.236664  0.008063 -0.203923     0.192958
# c_L2                         -0.001022  0.215053  0.058209    -0.089580
# d_L2                         -0.021814  0.117030 -0.030159    -0.031574
# model_leaf_length_L2          0.176886  0.233225 -0.022413     0.055348
#
#                           yield_originaal_moisture  yield_dry  yield_standard  \
# canopy_cover                              0.330251   0.336366        0.336366
# Weight                                    1.000000   0.991790        0.991790
# Moisture                                  0.146985   0.040535        0.040535
# Test.Weight                              -0.181027  -0.121414       -0.121414
# yield_originaal_moisture                  1.000000   0.991790        0.991790
# ...                                            ...        ...             ...
# a_L2                                      0.040943   0.066824        0.066824
# b_L2                                      0.008063   0.032346        0.032346
# c_L2                                      0.215053   0.205832        0.205832
# d_L2                                      0.117030   0.120402        0.120402
# model_leaf_length_L2                      0.233225   0.236630        0.236630
#
#                           yield_standard_bu  yield_dry_gm  \
# canopy_cover                       0.324201      0.336366
# Weight                             0.989930      0.991790
# Moisture                           0.118899      0.040535
# Test.Weight                       -0.264183     -0.121414
# yield_originaal_moisture           0.989930      0.991790
# ...                                     ...           ...
# a_L2                               0.034412      0.066824
# b_L2                              -0.001311      0.032346
# c_L2                               0.212950      0.205832
# d_L2                               0.121264      0.120402
# model_leaf_length_L2               0.217334      0.236630
#
#                           dry_matter/plant(kg)  ...  Stem.Angle_L2     A1_L2  \
# canopy_cover                          0.025760  ...       0.044907 -0.086045
# Weight                                0.762242  ...      -0.101808  0.021132
# Moisture                              0.077079  ...      -0.005562  0.183633
# Test.Weight                          -0.103325  ...       0.007796 -0.170765
# yield_originaal_moisture              0.762242  ...      -0.101808  0.021132
# ...                                        ...  ...            ...       ...
# a_L2                                  0.027490  ...       0.272720 -0.509852
# b_L2                                 -0.002932  ...       0.302476 -0.302363
# c_L2                                  0.255692  ...      -0.466469  0.359166
# d_L2                                  0.161612  ...      -0.292142  0.202047
# model_leaf_length_L2                  0.238015  ...      -0.249064 -0.111717
#
#                              N1_L2     A2_L2     N2_L2      a_L2      b_L2  \
# canopy_cover              0.043994  0.156005  0.045471  0.176139  0.236664
# Weight                    0.023972  0.043394  0.056249  0.040943  0.008063
# Moisture                 -0.134975 -0.096444 -0.033944 -0.181117 -0.203923
# Test.Weight               0.132225  0.068859  0.012404  0.152330  0.192958
# yield_originaal_moisture  0.023972  0.043394  0.056249  0.040943  0.008063
# ...                            ...       ...       ...       ...       ...
# a_L2                      0.427321  0.028030 -0.039463  1.000000  0.654276
# b_L2                      0.203917  0.515952  0.218889  0.654276  1.000000
# c_L2                     -0.198920  0.089335  0.238351 -0.120407 -0.171606
# d_L2                     -0.084254  0.293514  0.434540  0.051586 -0.001871
# model_leaf_length_L2      0.181809  0.242007  0.210260  0.331954  0.466996
#
#                               c_L2      d_L2  model_leaf_length_L2
# canopy_cover             -0.001022 -0.021814              0.176886
# Weight                    0.215053  0.117030              0.233225
# Moisture                  0.058209 -0.030159             -0.022413
# Test.Weight              -0.089580 -0.031574              0.055348
# yield_originaal_moisture  0.215053  0.117030              0.233225
# ...                            ...       ...                   ...
# a_L2                     -0.120407  0.051586              0.331954
# b_L2                     -0.171606 -0.001871              0.466996
# c_L2                      1.000000  0.749350              0.437649
# d_L2                      0.749350  1.000000              0.082357
# model_leaf_length_L2      0.437649  0.082357              1.000000
#
# [201 rows x 201 columns]

# %%
cmap = 'seismic'
vmax,vmin = 1,-1

fig, ax = plt.subplots(1,2,figsize=(18,9))

i = 0
ax[i].imshow(np.array(pcorr), cmap=cmap, vmax=vmax, vmin=vmin)
ax[i].set_title('Pearson correlation')

i = 1
ax[i].imshow(np.array(scorr), cmap=cmap, vmax=vmax, vmin=vmin)
ax[i].set_title('Spearman correlation');

# %%
for i,c in enumerate(scorr.columns):
    print(i, '\t', c)
# Out:
# 0 	 canopy_cover
# 1 	 Weight
# 2 	 Moisture
# 3 	 Test.Weight
# 4 	 yield_originaal_moisture
# 5 	 yield_dry
# 6 	 yield_standard
# 7 	 yield_standard_bu
# 8 	 yield_dry_gm
# 9 	 dry_matter/plant(kg)
# 10 	 Ear_Leaf_Length (cm)
# 11 	 Ear_Leaf_Width (cm)
# 12 	 Ear_Leaf_Area (cm^2)
# 13 	 Ear_Height (cm)
# 14 	 Plant_Height (cm)
# 15 	 Ear_Leaf_N
# 16 	 Total_Leaf_N
# 17 	 AnthesisGDD
# 18 	 SilkingGDD
# 19 	 TLA (m2)
# 20 	 epd
# 21 	 ear_leaf_weight (g)
# 22 	 LAI
# 23 	 BLUE_2019702dronemean
# 24 	 BLUE_STD_2019702dronemean
# 25 	 GREEN_2019702dronemean
# 26 	 GREEN_STD_2019702dronemean
# 27 	 NDVI_2019702dronemean
# 28 	 NDVI_STD_2019702dronemean
# 29 	 NIR_2019702dronemean
# 30 	 NIR_STD_2019702dronemean
# 31 	 RED_2019702dronemean
# 32 	 RED_STD_2019702dronemean
# 33 	 RED_EDGE_2019702dronemean
# 34 	 RED_EDGE_STD_2019702dronemean
# 35 	 BGI_72_mean_2019702dronemean
# 36 	 BGI_72_STD_2019702dronemean
# 37 	 EVI_72_mean_2019702dronemean
# 38 	 EVI_72_STD_2019702dronemean
# 39 	 GNDVI_72_mean_2019702dronemean
# 40 	 GNDVI_72_STD_2019702dronemean
# 41 	 Ratio_72_mean_2019702dronemean
# 42 	 Ratio_72_STD_2019702dronemean
# 43 	 SAVI_72_mean_2019702dronemean
# 44 	 SAVI_72_STD_2019702dronemean
# 45 	 TVI_72_mean_2019702dronemean
# 46 	 TVI_72_STD_2019702dronemean
# 47 	 BLUE_2019715dronemean
# 48 	 BLUE_STD_2019715dronemean
# 49 	 GREEN_2019715dronemean
# 50 	 GREEN_STD_2019715dronemean
# 51 	 NDVI_2019715dronemean
# 52 	 NDVI_STD_2019715dronemean
# 53 	 NIR_2019715dronemean
# 54 	 NIR_STD_2019715dronemean
# 55 	 RED_2019715dronemean
# 56 	 RED_STD_2019715dronemean
# 57 	 RED_EDGE_2019715dronemean
# 58 	 RED_EDGE_STD_2019715dronemean
# 59 	 BGI_715_mean
# 60 	 BGI_715_STD
# 61 	 EVI_715_mean
# 62 	 EVI_715_STD
# 63 	 GNDVI_715_mean
# 64 	 GNDVI_715_STD
# 65 	 Ratio_715_mean
# 66 	 Ratio_715_STD
# 67 	 SAVI_715_mean
# 68 	 SAVI_715_STD
# 69 	 TVI_715_mean
# 70 	 TVI_715_STD
# 71 	 BLUE_2019728dronemean
# 72 	 BLUE_STD_2019728dronemean
# 73 	 GREEN_2019728dronemean
# 74 	 GREEN_STD_2019728dronemean
# 75 	 NDVI_2019728dronemean
# 76 	 NDVI_STD_2019728dronemean
# 77 	 NIR_2019728dronemean
# 78 	 NIR_STD_2019728dronemean
# 79 	 RED_2019728dronemean
# 80 	 RED_STD_2019728dronemean
# 81 	 RED_EDGE_2019728dronemean
# 82 	 RED_EDGE_STD_2019728dronemean
# 83 	 BGI_728_mean
# 84 	 BGI_728_STD
# 85 	 EVI_728_mean
# 86 	 EVI_728_STD
# 87 	 GNDVI_728_mean
# 88 	 GNDVI_728_STD
# 89 	 Ratio_728_mean
# 90 	 Ratio_728_STD
# 91 	 SAVI_728_mean
# 92 	 SAVI_728_STD
# 93 	 TVI_728_mean
# 94 	 TVI_728_STD
# 95 	 BLUE_2019812dronemean
# 96 	 BLUE_STD_2019812dronemean
# 97 	 GREEN_2019812dronemean
# 98 	 GREEN_STD_2019812dronemean
# 99 	 NDVI_2019812dronemean
# 100 	 NDVI_STD_2019812dronemean
# 101 	 NIR_2019812dronemean
# 102 	 NIR_STD_2019812dronemean
# 103 	 RED_2019812dronemean
# 104 	 RED_STD_2019812dronemean
# 105 	 RED_EDGE_2019812dronemean
# 106 	 RED_EDGE_STD_2019812dronemean
# 107 	 BGI_812_mean
# 108 	 BGI_812_STD
# 109 	 EVI_812_mean
# 110 	 EVI_812_STD
# 111 	 GNDVI_812_mean
# 112 	 GNDVI_812_STD
# 113 	 Ratio_812_mean
# 114 	 Ratio_812_STD
# 115 	 SAVI_812_mean
# 116 	 SAVI_812_STD
# 117 	 TVI_812_mean
# 118 	 TVI_812_STD
# 119 	 BLUE_2019902dronemean
# 120 	 BLUE_STD_2019902dronemean
# 121 	 GREEN_2019902dronemean
# 122 	 GREEN_STD_2019902dronemean
# 123 	 NDVI_2019902dronemean
# 124 	 NDVI_STD_2019902dronemean
# 125 	 NIR_2019902dronemean
# 126 	 NIR_STD_2019902dronemean
# 127 	 RED_2019902dronemean
# 128 	 RED_STD_2019902dronemean
# 129 	 RED_EDGE_2019902dronemean
# 130 	 RED_EDGE_STD_2019902dronemean
# 131 	 BGI_92_mean
# 132 	 BGI_92_STD
# 133 	 EVI_92_mean
# 134 	 EVI_92_STD
# 135 	 GNDVI_92_mean
# 136 	 GNDVI_92_STD
# 137 	 Ratio_92_mean
# 138 	 Ratio_92_STD
# 139 	 SAVI_92_mean
# 140 	 SAVI_92_STD
# 141 	 TVI_92_mean
# 142 	 TVI_92_STD
# 143 	 BLUE_2019911dronemean
# 144 	 BLUE_STD_2019911dronemean
# 145 	 GREEN_2019911dronemean
# 146 	 GREEN_STD_2019911dronemean
# 147 	 NDVI_2019911dronemean
# 148 	 NDVI_STD_2019911dronemean
# 149 	 NIR_2019911dronemean
# 150 	 NIR_STD_2019911dronemean
# 151 	 RED_2019911dronemean
# 152 	 RED_STD_2019911dronemean
# 153 	 RED_EDGE_2019911dronemean
# 154 	 RED_EDGE_STD_2019911dronemean
# 155 	 BGI_911_mean
# 156 	 BGI_911_STD
# 157 	 EVI_911_mean
# 158 	 EVI_911_STD
# 159 	 GNDVI_911_mean
# 160 	 GNDVI_911_STD
# 161 	 Ratio_911_mean
# 162 	 Ratio_911_STD
# 163 	 SAVI_911_mean
# 164 	 SAVI_911_STD
# 165 	 TVI_911_mean
# 166 	 TVI_911_STD
# 167 	 2019-07-02 00:00:00
# 168 	 2019-07-15 00:00:00
# 169 	 2019-07-28 00:00:00
# 170 	 2019-08-12 00:00:00
# 171 	 2019-09-02 00:00:00
# 172 	 2019-09-11 00:00:00
# 173 	 End.Angle_L1
# 174 	 End.Length_L1
# 175 	 Mid.Angle_L1
# 176 	 Mid.Length_L1
# 177 	 Stem.Angle_L1
# 178 	 A1_L1
# 179 	 N1_L1
# 180 	 A2_L1
# 181 	 N2_L1
# 182 	 a_L1
# 183 	 b_L1
# 184 	 c_L1
# 185 	 d_L1
# 186 	 model_leaf_length_L1
# 187 	 End.Angle_L2
# 188 	 End.Length_L2
# 189 	 Mid.Angle_L2
# 190 	 Mid.Length_L2
# 191 	 Stem.Angle_L2
# 192 	 A1_L2
# 193 	 N1_L2
# 194 	 A2_L2
# 195 	 N2_L2
# 196 	 a_L2
# 197 	 b_L2
# 198 	 c_L2
# 199 	 d_L2
# 200 	 model_leaf_length_L2

# %%
#ss = list(range(23)) + list(range(167, len(scorr)))

ss = [0] + list(range(10, 23)) + list(range(167, 178)) + list(range(187, 192))

# %%
sns.clustermap(scorr.iloc[ss, ss], method='complete', vmax=vmax, vmin=vmin, cmap=cmap);
plt.subplots_adjust(top=0.9)
plt.suptitle('Spearman correlation', fontsize=28);

#filename = dst + 'spearman_correlation_sub.jpg'
#plt.savefig(filename, dpi=130, format='jpg', pil_kwargs={'optimize':True}, bbox_inches='tight')

# %%
sns.clustermap(pcorr.iloc[ss,ss], method='complete', vmax=vmax, vmin=vmin, cmap=cmap);
plt.subplots_adjust(top=0.9)
plt.suptitle('Pearson correlation', fontsize=28);
# Out:
# Text(0.5, 0.98, 'Pearson correlation')

# %% [markdown]
# # Sklearn

# %%
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVR
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import confusion_matrix
from sklearn.preprocessing import StandardScaler

# %%
cols = list(data.columns.values)
for i in range(len(cols)):
    print(i, '\t', cols[i])
# Out:
# 0 	 plot
# 1 	 New_Source
# 2 	 New_Pedigree
# 3 	 Old_Pedigree
# 4 	 Old_Source
# 5 	 Shared
# 6 	 New_Family
# 7 	 Tester
# 8 	 Pass
# 9 	 Range
# 10 	 Group.1
# 11 	 Rep
# 12 	 Date.Time
# 13 	 Harvest.Sequence
# 14 	 X
# 15 	 Stand.Count
# 16 	 GreenSnap
# 17 	 Root Lodging
# 18 	 Stalk Lodging
# 19 	 canopy_cover
# 20 	 Weight
# 21 	 Moisture
# 22 	 Test.Weight
# 23 	 yield_originaal_moisture
# 24 	 yield_dry
# 25 	 yield_standard
# 26 	 yield_standard_bu
# 27 	 yield_dry_gm
# 28 	 dry_matter/plant(kg)
# 29 	 Ear_Leaf_Length (cm)
# 30 	 Ear_Leaf_Width (cm)
# 31 	 Ear_Leaf_Area (cm^2)
# 32 	 Ear_Height (cm)
# 33 	 Plant_Height (cm)
# 34 	 Ear_Leaf_N
# 35 	 Total_Leaf_N
# 36 	 AnthesisGDD
# 37 	 SilkingGDD
# 38 	 TLA (m2)
# 39 	 epd
# 40 	 ear_leaf_weight (g)
# 41 	 LAI
# 42 	 BLUE_2019702dronemean
# 43 	 BLUE_STD_2019702dronemean
# 44 	 GREEN_2019702dronemean
# 45 	 GREEN_STD_2019702dronemean
# 46 	 NDVI_2019702dronemean
# 47 	 NDVI_STD_2019702dronemean
# 48 	 NIR_2019702dronemean
# 49 	 NIR_STD_2019702dronemean
# 50 	 RED_2019702dronemean
# 51 	 RED_STD_2019702dronemean
# 52 	 RED_EDGE_2019702dronemean
# 53 	 RED_EDGE_STD_2019702dronemean
# 54 	 BGI_72_mean_2019702dronemean
# 55 	 BGI_72_STD_2019702dronemean
# 56 	 EVI_72_mean_2019702dronemean
# 57 	 EVI_72_STD_2019702dronemean
# 58 	 GNDVI_72_mean_2019702dronemean
# 59 	 GNDVI_72_STD_2019702dronemean
# 60 	 Ratio_72_mean_2019702dronemean
# 61 	 Ratio_72_STD_2019702dronemean
# 62 	 SAVI_72_mean_2019702dronemean
# 63 	 SAVI_72_STD_2019702dronemean
# 64 	 TVI_72_mean_2019702dronemean
# 65 	 TVI_72_STD_2019702dronemean
# 66 	 BLUE_2019715dronemean
# 67 	 BLUE_STD_2019715dronemean
# 68 	 GREEN_2019715dronemean
# 69 	 GREEN_STD_2019715dronemean
# 70 	 NDVI_2019715dronemean
# 71 	 NDVI_STD_2019715dronemean
# 72 	 NIR_2019715dronemean
# 73 	 NIR_STD_2019715dronemean
# 74 	 RED_2019715dronemean
# 75 	 RED_STD_2019715dronemean
# 76 	 RED_EDGE_2019715dronemean
# 77 	 RED_EDGE_STD_2019715dronemean
# 78 	 BGI_715_mean
# 79 	 BGI_715_STD
# 80 	 EVI_715_mean
# 81 	 EVI_715_STD
# 82 	 GNDVI_715_mean
# 83 	 GNDVI_715_STD
# 84 	 Ratio_715_mean
# 85 	 Ratio_715_STD
# 86 	 SAVI_715_mean
# 87 	 SAVI_715_STD
# 88 	 TVI_715_mean
# 89 	 TVI_715_STD
# 90 	 BLUE_2019728dronemean
# 91 	 BLUE_STD_2019728dronemean
# 92 	 GREEN_2019728dronemean
# 93 	 GREEN_STD_2019728dronemean
# 94 	 NDVI_2019728dronemean
# 95 	 NDVI_STD_2019728dronemean
# 96 	 NIR_2019728dronemean
# 97 	 NIR_STD_2019728dronemean
# 98 	 RED_2019728dronemean
# 99 	 RED_STD_2019728dronemean
# 100 	 RED_EDGE_2019728dronemean
# 101 	 RED_EDGE_STD_2019728dronemean
# 102 	 BGI_728_mean
# 103 	 BGI_728_STD
# 104 	 EVI_728_mean
# 105 	 EVI_728_STD
# 106 	 GNDVI_728_mean
# 107 	 GNDVI_728_STD
# 108 	 Ratio_728_mean
# 109 	 Ratio_728_STD
# 110 	 SAVI_728_mean
# 111 	 SAVI_728_STD
# 112 	 TVI_728_mean
# 113 	 TVI_728_STD
# 114 	 BLUE_2019812dronemean
# 115 	 BLUE_STD_2019812dronemean
# 116 	 GREEN_2019812dronemean
# 117 	 GREEN_STD_2019812dronemean
# 118 	 NDVI_2019812dronemean
# 119 	 NDVI_STD_2019812dronemean
# 120 	 NIR_2019812dronemean
# 121 	 NIR_STD_2019812dronemean
# 122 	 RED_2019812dronemean
# 123 	 RED_STD_2019812dronemean
# 124 	 RED_EDGE_2019812dronemean
# 125 	 RED_EDGE_STD_2019812dronemean
# 126 	 BGI_812_mean
# 127 	 BGI_812_STD
# 128 	 EVI_812_mean
# 129 	 EVI_812_STD
# 130 	 GNDVI_812_mean
# 131 	 GNDVI_812_STD
# 132 	 Ratio_812_mean
# 133 	 Ratio_812_STD
# 134 	 SAVI_812_mean
# 135 	 SAVI_812_STD
# 136 	 TVI_812_mean
# 137 	 TVI_812_STD
# 138 	 BLUE_2019902dronemean
# 139 	 BLUE_STD_2019902dronemean
# 140 	 GREEN_2019902dronemean
# 141 	 GREEN_STD_2019902dronemean
# 142 	 NDVI_2019902dronemean
# 143 	 NDVI_STD_2019902dronemean
# 144 	 NIR_2019902dronemean
# 145 	 NIR_STD_2019902dronemean
# 146 	 RED_2019902dronemean
# 147 	 RED_STD_2019902dronemean
# 148 	 RED_EDGE_2019902dronemean
# 149 	 RED_EDGE_STD_2019902dronemean
# 150 	 BGI_92_mean
# 151 	 BGI_92_STD
# 152 	 EVI_92_mean
# 153 	 EVI_92_STD
# 154 	 GNDVI_92_mean
# 155 	 GNDVI_92_STD
# 156 	 Ratio_92_mean
# 157 	 Ratio_92_STD
# 158 	 SAVI_92_mean
# 159 	 SAVI_92_STD
# 160 	 TVI_92_mean
# 161 	 TVI_92_STD
# 162 	 BLUE_2019911dronemean
# 163 	 BLUE_STD_2019911dronemean
# 164 	 GREEN_2019911dronemean
# 165 	 GREEN_STD_2019911dronemean
# 166 	 NDVI_2019911dronemean
# 167 	 NDVI_STD_2019911dronemean
# 168 	 NIR_2019911dronemean
# 169 	 NIR_STD_2019911dronemean
# 170 	 RED_2019911dronemean
# 171 	 RED_STD_2019911dronemean
# 172 	 RED_EDGE_2019911dronemean
# 173 	 RED_EDGE_STD_2019911dronemean
# 174 	 BGI_911_mean
# 175 	 BGI_911_STD
# 176 	 EVI_911_mean
# 177 	 EVI_911_STD
# 178 	 GNDVI_911_mean
# 179 	 GNDVI_911_STD
# 180 	 Ratio_911_mean
# 181 	 Ratio_911_STD
# 182 	 SAVI_911_mean
# 183 	 SAVI_911_STD
# 184 	 TVI_911_mean
# 185 	 TVI_911_STD
# 186 	 2019-07-02 00:00:00
# 187 	 2019-07-15 00:00:00
# 188 	 2019-07-28 00:00:00
# 189 	 2019-08-12 00:00:00
# 190 	 2019-09-02 00:00:00
# 191 	 2019-09-11 00:00:00
# 192 	 End.Angle_L1
# 193 	 End.Length_L1
# 194 	 Mid.Angle_L1
# 195 	 Mid.Length_L1
# 196 	 Stem.Angle_L1
# 197 	 A1_L1
# 198 	 N1_L1
# 199 	 A2_L1
# 200 	 N2_L1
# 201 	 a_L1
# 202 	 b_L1
# 203 	 c_L1
# 204 	 d_L1
# 205 	 model_leaf_length_L1
# 206 	 End.Angle_L2
# 207 	 End.Length_L2
# 208 	 Mid.Angle_L2
# 209 	 Mid.Length_L2
# 210 	 Stem.Angle_L2
# 211 	 A1_L2
# 212 	 N1_L2
# 213 	 A2_L2
# 214 	 N2_L2
# 215 	 a_L2
# 216 	 b_L2
# 217 	 c_L2
# 218 	 d_L2
# 219 	 model_leaf_length_L2

# %%
colss = cols[15:17] + [cols[20]] + cols[29:42]
#colss += cols[192:197] + cols[206:211] 
#colss += cols[197:206] + cols[211:] 

pheno = data.loc[:, colss].copy()
pheno_scaled = StandardScaler().fit_transform(pheno)
pheno
# Out:
#      Stand.Count  GreenSnap  Weight  Ear_Leaf_Length (cm)  \
# 0             84          0   22.01                 84.50
# 1             82          0   17.20                 88.10
# 2             72          0   20.66                 91.95
# 3             86          0   19.37                 70.25
# 4             90          0   27.17                 91.00
# ..           ...        ...     ...                   ...
# 363           86          0   22.81                 91.00
# 364           71          0   22.72                 91.70
# 365           88          0   25.55                 91.20
# 366           86          0   24.78                 90.45
# 367           86          0   20.72                 89.55
#
#      Ear_Leaf_Width (cm)  Ear_Leaf_Area (cm^2)  Ear_Height (cm)  \
# 0                   9.75             617.90625            113.5
# 1                   9.60             634.32000            120.0
# 2                  10.00             689.62500             99.0
# 3                   9.60             505.80000            134.0
# 4                  10.20             696.15000            121.5
# ..                   ...                   ...              ...
# 363                 8.65             590.36250             99.0
# 364                10.30             708.38250            105.5
# 365                 9.10             622.44000            114.5
# 366                10.00             678.37500            105.5
# 367                 8.40             564.16500             82.0
#
#      Plant_Height (cm)  Ear_Leaf_N  Total_Leaf_N  AnthesisGDD  SilkingGDD  \
# 0                199.0        12.5          17.5      1192.25     1247.60
# 1                214.0        12.5          17.5      1247.60     1270.20
# 2                205.5        12.5          18.5      1227.50     1270.20
# 3                219.0        13.5          18.5      1247.60     1270.20
# 4                232.5        13.0          18.0      1150.25     1247.60
# ..                 ...         ...           ...          ...         ...
# 363              198.0        11.5          16.5      1192.25     1247.60
# 364              202.0        11.0          16.0      1209.45     1247.60
# 365              223.0        12.5          18.5      1192.25     1293.55
# 366              205.5        12.0          17.5      1174.60     1227.50
# 367              171.0        11.0          16.5      1209.45     1227.50
#
#      TLA (m2)        epd  ear_leaf_weight (g)       LAI
# 0    0.507814  69.090323                  7.0  4.174086
# 1    0.521303  85.590164                  6.5  4.182941
# 2    0.621483  76.621053                  8.2  4.378639
# 3    0.436974  70.062637                  6.0  3.677318
# 4    0.600025  64.150000                  7.7  5.284322
# ..        ...        ...                  ...       ...
# 363  0.459177  76.621053                  6.6  3.864167
# 364  0.543334  76.621053                  7.8  3.774875
# 365  0.560937  75.313158                  7.4  4.830296
# 366  0.568958  83.661905                  7.6  4.788024
# 367  0.446286  96.225000                  6.4  3.755683
#
# [368 rows x 16 columns]

# %%
#y = data['canopy_cover'].values
y = data['2019-07-02 00:00:00'].values

y_scaled = (y - y.mean())/y.std()

# %%
svr = SVR(kernel='rbf', C=10, gamma=0.01, epsilon=.1)
svr = SVR(kernel='poly', C=10, gamma=0.1, degree=3, epsilon=0.1, coef0=1)
#svr = SVR(kernel='linear', C=10, gamma=0.1)

# %%
ypred = svr.fit(pheno_scaled, y_scaled).predict(pheno_scaled)
print(svr.score(pheno_scaled, y_scaled))
# Out:
# 0.939220802051525

# %%
xaxis = np.linspace(np.min(y_scaled), np.max(y_scaled), 10)
plt.figure(figsize=(18,5))
plt.plot(y_scaled, ypred,'.r', label='predicted')
#plt.plot(ypred, '.b', label='predicted');
plt.plot(xaxis, xaxis, 'b', label='y=x')
plt.legend();

# %%
print(X_train.shape, X_test.shape)
# Out:
# (276, 16) (92, 16)

# %%
X_train, X_test, y_train, y_test = train_test_split(pheno_scaled,
                                                    y_scaled,
                                                    test_size=0.25)

# %%
#svr_params = {'C':10, 'kernel':'rbf', 'gamma':0.01, 'epsilon':.01}
svr_params = {'kernel':'poly', 'C':10, 'gamma':0.1, 'degree':3, 'epsilon':0.01, 'coef0':1}
svr = SVR(**svr_params).fit(X_train, y_train)
print(svr.score(X_test, y_test))
# Out:
# -4.11375956012884

# %%
ypred = svr.predict(X_test)

xaxis = np.linspace(np.min(y_test), np.max(y_test), 10)
plt.figure(figsize=(18,5))
plt.plot(y_test, ypred,'.r', label='predicted')
#plt.plot(ypred, '.b', label='predicted');
plt.plot(xaxis, xaxis, 'b', label='y=x')
plt.legend();

# %%
svr_params = {'C':50, 'kernel':'rbf', 'gamma':0.0009, 'epsilon':.01}
#svr_params = {'C':10, 'kernel':'poly', 'gamma':'auto', 'epsilon':0.01, 'degree':2, 'coef0':1}

N = 1000
score = np.zeros(N)

for i in range(N):
    X_train, X_test, y_train, y_test = train_test_split(pheno_scaled, y_scaled, test_size=0.2)
    svr = SVR(**svr_params).fit(X_train, y_train)
    score[i] = svr.score(X_test, y_test)
    
ax = sns.boxplot(x=score)
ax.set_title('Average: {:.2f}'.format(np.mean(score)));

# %% [markdown]
# ### Using `y = canopy_cover` (scaled)
#
# - polynomial kernels do not work for trad phenotypes
# - 0.44 with radial kernel $\gamma = 0.01$
# - 0.47 with $\gamma = 0.008$
#
#
# - 0.37 with radial kernel $\gamma = 0.01$ for trad+ext phenotypes
# - 0.47 with $\gamma = 0.001$
# - 0.31 for poly 3
# - 0.31 for poly 4
#
#
# - 0.34 with radial kernel $\gamma = 0.01$ and trad+ext+model phenotypes
# - 0.38 with radial kernel $\gamma = 0.005$
# - 0.43 with radial kernel $\gamma = 0.002$
# - 0.16 with poly kernel, deg 4
# - 0.12 with poly kernel, deg 3
#
# Watch out for very negative $R^2$ scores!

# %% [markdown]
# ### Using `y = drone[190702]` (scaled)
#
# - 0.38 with radial kernel $\gamma=0.01$ for trad phenotypes
# - 0.36 with $\gamma=0.1$
# - Polynomial kernels do not work
#
#
# - 0.38 with radial kernel $\gamma=0.01$ for trad+ext phenotypes
# - 0.30 for $\gamma=0.02$
# - 0.37 for $\gamma=0.08$
# - 0.20 for poly kernel deg 2, c0 = 1
# - 0.29 for deg 3
# - 0.32 for deg 4
#
#
# - 0.39 with radial kernel $\gamma=0.008$ for trad+ext+model phenotypes
# - 0.37 with $\gamma=0.01$
# - 0.42 with $\gamma=0.002$
# - 0.24 for poly kernel (deg 3, c0 = 3)
# - 0.24 for poly kernel (deg 3, c0 = 1)
# - 0.30 for deg 4
# - 0.18 for deg 2
# - 0.21 for deg 2, $\gamma=0.008$

# %% [markdown]
# ### Using `y = canopy_cover` (unscaled)
#
# - 0.15 with radial kernel and trad phenotypes
# - This is down from 0.24 when the data set is expanded
# - 0.24 actually achieved with $\gamma = 0.1$
# - Pushed up to 0.30 with $\gamma = 0.05$
# - poly kernel doesn't work
#
#
# - 0.39 with radial kernel and trad+ext phenotypes ($\gamma = 0.005$)
# - 0.35 with $\gamma = 0.01$
# - poly kernel doesn't work
#
#
# - 0.33 with radial kernel $\gamma=0.01$ and trad+ext+model phenotypes
# - 0.24 with poly kernel, deg 3
# - 0.16 with poly kernel, deg 2
# - 0.25 with poly kernel, deg 4
#
# Watch out for very negative $R^2$ scores!

# %% [markdown]
# ### Using `y = drone[190702]` (unscaled)
#
# - 0.41 with traditional phenotypes
#
#
#
# - 0.17 with radial kernel and trad phenotyes ($\gamma=0.05$)
# - Similar results with polynomial kernel
#
#
# - Similar results with radial kernel for trad+ext phenotypes
# - 0.24 for poly kernel (deg 3, c0 = 3)
# - 0.29 for poly kernel (deg 3, c0 = 1)
# - 0.32 for deg 4
# - 0.36 for deg 2

# %% [markdown]
# # Ridge Regression

# %%
from sklearn.linear_model import Ridge

# %%
ridge_params = {'alpha':0.7, 'fit_intercept':False}

N = 1000
score = np.zeros(N)

for i in range(N):
    X_train, X_test, y_train, y_test = train_test_split(pheno_scaled, y_scaled, test_size=0.25)
    clf = Ridge(**ridge_params).fit(X_train, y_train)
    score[i] = clf.score(X_test, y_test)
    
ax = sns.boxplot(x=score)
ax.set_title('Average: {:.2f}'.format(np.mean(score)));

# %% [markdown]
# ### `y = canopy_cover` (scaled)
#
# - 0.29 with $\alpha=0.1$ for trad phenotypes
# - 0.30 for $\alpha=0.01$
# - 0.34 by setting `False` intercept fit
#
#
# - 0.32 with $\alpha=0.5$ for trad+ext phenotypes
#
#
# - 0.19 with $\alpha=1$ for trad+ext+model phenotypes

# %% [markdown]
# ### `y = drone[190702]` (scaled)
#
# - 0.50 with $\alpha = 0.75$ for trad phenotypes
#
#
# - 0.43 with $\alpha = 0.43$ for trad+ext phenotypes
#
#
# - 0.38 with $\alpha=1$ for trad+ext+model phenotypes

# %% [markdown]
# # PCA

# %%
y_var = (y - y.min())/(y.max() - y.min())

# %%
from sklearn.decomposition import PCA, KernelPCA

# %%
pca = PCA(n_components=2)
pca.fit(pheno_scaled)

print(pca.explained_variance_ratio_)

print(pca.singular_values_)
# Out:
# [0.18671445 0.12415627]
# [36.93926407 30.1219859 ]

# %%
prcomp = pca.transform(pheno_scaled)

# %%
plt.figure(figsize=(18,5))

plt.scatter(prcomp[:,0], prcomp[:,1], c=y_var, cmap='inferno');

# %% [markdown]
# # KPCA

# %%
kpca = KernelPCA(n_components=2, kernel="rbf", fit_inverse_transform=False, gamma=0.3)
X_kpca = kpca.fit_transform(pheno_scaled)

# %%
plt.figure(figsize=(18,5))

plt.scatter(X_kpca[:,0], X_kpca[:,1], c=y_var, cmap='inferno');

# %%
#
